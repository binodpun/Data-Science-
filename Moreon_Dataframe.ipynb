# %% [markdown]
# <a href="https://colab.research.google.com/github/binodpun/Data-Science-/blob/main/Moreon_Dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.DataFrame({'movie name' : ['pk', 'fighter', 'lost lady'],
                   'actor': ['Amir', 'Hritik', 'Willa']}


)

# %%
df
# Out:
#   movie name   actor
# 0         pk    Amir
# 1    fighter  Hritik
# 2  lost lady   Willa

# %%
df['movie name'] # df['column name']
# Out:
# 0           pk
# 1      fighter
# 2    lost lady
# Name: movie name, dtype: object

# %%
df. move name # df.column name is invalid if column name contains space or any special character
# Out:
#   File "<ipython-input-15-cef65da8f88d>", line 1
#     df. move name # df.column name is invalid if column name contains space or any special character
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# # I want to rename move name column to movie_name

# %%
df.columns
# Out:
# Index(['movie name', 'actor'], dtype='object')

# %%
df.rename({'movie name' : 'movie_name'}, axis = 'columns', inplace= True)

# %%
df
# Out:
#   movie_name   actor
# 0         pk    Amir
# 1    fighter  Hritik
# 2  lost lady   Willa

# %% [markdown]
# # adding a new column name

# %%
df
# Out:
#   movie_name   actor
# 0         pk    Amir
# 1    fighter  Hritik
# 2  lost lady   Willa

# %%
df['days'] = [10, 50, 40]

# %%
df
# Out:
#   movie_name   actor  days
# 0         pk    Amir    10
# 1    fighter  Hritik    50
# 2  lost lady   Willa    40

# %% [markdown]
# # deleting a column in dataframe

# %%
df.drop(columns=['days'], inplace=True)

# %%
df
# Out:
#   movie_name   actor
# 0         pk    Amir
# 1    fighter  Hritik
# 2  lost lady   Willa

# %% [markdown]
# # Missing values

# %%
df = pd.DataFrame([{'a' : 1, 'c' : 3}, {"a": 2, 'b' : 22, 'c' : 5}])
df
# Out:
#    a  c     b
# 0  1  3   NaN
# 1  2  5  22.0

# %%
# NaN means missing data or value
# how to check if data is missing or not

# %%
df.isna()
# Out:
#        a      c      b
# 0  False  False   True
# 1  False  False  False

# %%
df.isnull()
# Out:
#        a      c      b
# 0  False  False   True
# 1  False  False  False

# %%
df.b[0]
# Out:
# nan

# %%
# kun column ma kati no. of data missing?

# %%
False + False
# Out:
# 0

# %%
True + True
# Out:
# 2

# %%
True + False
# Out:
# 1

# %%
df.isna().sum()
# Out:
# a    0
# c    0
# b    1
# dtype: int64
