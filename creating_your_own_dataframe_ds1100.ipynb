# %% [markdown]
# <a href="https://colab.research.google.com/github/binodpun/Data-Science-/blob/main/creating_your_own_dataframe_ds1100.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data = {
    "name": ['Ram', 'Shyam', 'Sita', 'Rita', 'Gita'],
    "gender": ['Male', 'Male', 'Female', 'Female', 'Female'],
    "age": [22,20,24,21,22]
}

# %%
data
# Out:
# {'name': ['Ram', 'Shyam', 'Sita', 'Rita', 'Gita'],
#  'gender': ['Male', 'Male', 'Female', 'Female', 'Female'],
#  'age': [22, 20, 24, 21, 22]}

# %%
import pandas as pd

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#     name  gender  age
# 0    Ram    Male   22
# 1  Shyam    Male   20
# 2   Sita  Female   24
# 3   Rita  Female   21
# 4   Gita  Female   22

# %%
df['name']
# Out:
# 0      Ram
# 1    Shyam
# 2     Sita
# 3     Rita
# 4     Gita
# Name: name, dtype: object

# %%
df['gender']
# Out:
# 0      Male
# 1      Male
# 2    Female
# 3    Female
# 4    Female
# Name: gender, dtype: object

# %%
df['age']
# Out:
# 0    22
# 1    20
# 2    24
# 3    21
# 4    22
# Name: age, dtype: int64

# %%
df['age'] <=21
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# Name: age, dtype: bool

# %%
df[df['age'] <=21]
# Out:
#     name  gender  age
# 1  Shyam    Male   20
# 3   Rita  Female   21

# %%
df.loc[df['age'] <=21]
# Out:
#     name  gender  age
# 1  Shyam    Male   20
# 3   Rita  Female   21

# %%
df
# Out:
#     name  gender  age
# 0    Ram    Male   22
# 1  Shyam    Male   20
# 2   Sita  Female   24
# 3   Rita  Female   21
# 4   Gita  Female   22

# %%
# extract data of Female only

# %%
df.loc[df['gender'] == 'Female']
# Out:
#    name  gender  age
# 2  Sita  Female   24
# 3  Rita  Female   21
# 4  Gita  Female   22

# %%
df[df['gender'] == 'Male']
# Out:
#     name gender  age
# 0    Ram   Male   22
# 1  Shyam   Male   20
